# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Problem Statement 10: (Fix the header)
# Import the hospital data from Data/hospitals.csv and make the necessary changes to the header (Do not change the original file). The header uses acronyms that are defined in metadata.csv. Find the data and rename the headers so that it is more understandable to users who are not familiar with the acronyms. The First cell in the header is missing which should be renamed to State/UT. Rename the other headers in a uniform format.

# %%
df_hospital_raw = pd.read_csv("C:/Users/raiti/OneDrive/Desktop/Projects/Python Project Healthcare/Python Project - Healthcare Census/Data/hospitals.csv")
df_hospital = df_hospital_raw.copy()
df_hospital
# Out:
#                    Unnamed: 0     PHC    CHC    SDH     DH Hospitals  \
# 0   Andaman & Nicobar Islands      27      4    NaN      3        34
# 1              Andhra Pradesh    1417    198     31     20      1666
# 2           Arunachal Pradesh     122     62    NaN     15       199
# 3                       Assam    1007    166     14     33      1220
# 4                       Bihar    2007     63     33     43      2146
# 5                  Chandigarh      40      2      1      4        47
# 6                Chhattisgarh     813    166     12     32      1023
# 7        Dadra & Nagar Haveli       9      2      1      1        13
# 8                 Daman & Diu       4      2    NaN      2         8
# 9                       Delhi     534     25      9     47       615
# 10                        Goa      31      4      2      3        40
# 11                    Gujarat    1770    385     44     37      2236
# 12                    Haryana     500    131     24     28       683
# ...

# %%
df_hospital.columns = ['State/UT', 'Number of Primary Health Centers(PHCs)', 'Community Health Centers(CHCs)', 'Sub-District/Divisional Hospitals(SDHs)', 'District Hospitals(DHs)', 'Hospitals',
       'HospitalBeds']

# %%
df_hospital
# Out:
#                      State/UT Number of Primary Health Centers(PHCs)  \
# 0   Andaman & Nicobar Islands                                     27
# 1              Andhra Pradesh                                   1417
# 2           Arunachal Pradesh                                    122
# 3                       Assam                                   1007
# 4                       Bihar                                   2007
# 5                  Chandigarh                                     40
# 6                Chhattisgarh                                    813
# 7        Dadra & Nagar Haveli                                      9
# 8                 Daman & Diu                                      4
# 9                       Delhi                                    534
# 10                        Goa                                     31
# 11                    Gujarat                                   1770
# 12                    Haryana                                    500
# ...

# %% [markdown]
# ## Problem Statement 11: (Create a function to alter the data to create uniformity)
# The State/UT names have some different formats compared to other census and housing data. Manually identify those differences and fix them so that the State/UT names match exactly with the census and housing data.
# A function should be created to perform this operation. Since the same operation is required for another dataset as well.
# After the process save the data in a CSV file named “all_hospitals.csv” in the “Clean_Data” folder

# %%
df_census = pd.read_csv("C:/Users/raiti/OneDrive/Desktop/Projects/Python Project Healthcare/Python Project - Healthcare Census/Data/census_2011.csv")# usecols = [lambda x:x for x not in ['Unnamed: 0']])
# df_census = df_census.drop(['Unnamed: 0'], axis = 1)
df_census
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df_census.columns = ['District code', 'State/UT', 'District name', 'Population',
       'Male', 'Female', 'Literate', 'Male_Literate', 'Female_Literate',
       'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST',
       'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers',
       'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers',
       'Agricultural_Workers', 'Household_Workers', 'Other_Workers',
       'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
       'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households',
       'Housholds_with_Electric_Lighting', 'Households_with_Internet',
       'Households_with_Computer', 'Rural_Households', 'Urban_Households',
       'Households', 'Below_Primary_Education', 'Primary_Education',
       'Middle_Education', 'Secondary_Education', 'Higher_Education',
       'Graduate_Education', 'Other_Education', 'Literate_Education',
       'Illiterate_Education', 'Total_Education', 'Age_Group_0_29',
       'Age_Group_30_49', 'Age_Group_50', 'Age not stated',
       'Households_with_Bicycle', 'Households_with_Car_Jeep_Van',
       'Households_with_Radio_Transistor',
       'Households_with_Scooter_Motorcycle_Moped',
       'Households_with_Telephone_Mobile_Phone_Landline_only',
       'Households_with_Telephone_Mobile_Phone_Mobile_only',
       'Households_with_TV_Computer_Laptop_Telephone_mobile_phone_and_Scooter_Car',
       'Households_with_Television',
       'Households_with_Telephone_Mobile_Phone',
       'Households_with_Telephone_Mobile_Phone_Both',
       'Condition_of_occupied_census_houses_Dilapidated_Households',
       'Households_with_separate_kitchen_Cooking_inside_house',
       'Having_bathing_facility_Total_Households',
       'Having_latrine_facility_within_the_premises_Total_Households',
       'Ownership_Owned_Households', 'Ownership_Rented_Households',
       'Type_of_bathing_facility_Enclosure_without_roof_Households',
       'Type_of_fuel_used_for_cooking_Any_other_Households',
       'Type_of_latrine_facility_Pit_latrine_Households',
       'Type_of_latrine_facility_Other_latrine_Households',
       'Type_of_latrine_facility_Night_soil_disposed_into_open_drain_Households',
       'Type_of_latrine_facility_Flush_pour_flush_latrine_connected_to_other_system_Households',
       'Not_having_bathing_facility_within_the_premises_Total_Households',
       'Not_having_latrine_facility_within_the_premises_Alternative_source_Open_Households',
       'Main_source_of_drinking_water_Un_covered_well_Households',
       'Main_source_of_drinking_water_Handpump_Tubewell_Borewell_Households',
       'Main_source_of_drinking_water_Spring_Households',
       'Main_source_of_drinking_water_River_Canal_Households',
       'Main_source_of_drinking_water_Other_sources_Households',
       'Main_source_of_drinking_water_Other_sources_Spring_River_Canal_Tank_Pond_Lake_Other_sources__Households',
       'Location_of_drinking_water_source_Near_the_premises_Households',
       'Location_of_drinking_water_source_Within_the_premises_Households',
       'Main_source_of_drinking_water_Tank_Pond_Lake_Households',
       'Main_source_of_drinking_water_Tapwater_Households',
       'Main_source_of_drinking_water_Tubewell_Borehole_Households',
       'Household_size_1_person_Households',
       'Household_size_2_persons_Households',
       'Household_size_1_to_2_persons',
       'Household_size_3_persons_Households',
       'Household_size_3_to_5_persons_Households',
       'Household_size_4_persons_Households',
       'Household_size_5_persons_Households',
       'Household_size_6_8_persons_Households',
       'Household_size_9_persons_and_above_Households',
       'Location_of_drinking_water_source_Away_Households',
       'Married_couples_1_Households', 'Married_couples_2_Households',
       'Married_couples_3_Households',
       'Married_couples_3_or_more_Households',
       'Married_couples_4_Households', 'Married_couples_5__Households',
       'Married_couples_None_Households',
       'Power_Parity_Less_than_Rs_45000', 'Power_Parity_Rs_45000_90000',
       'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
       'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
       'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
       'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
       'Power_Parity_Above_Rs_545000', 'Total_Power_Parity']

# %%
def capital(st):
    for i in range(0,len(st)):
        st[i] = st[i].capitalize()
    st = ' '.join(st)
    return st

def lowerAnd(st):
    st = st.split()
    for i in range(0,len(st)):
        if st[i] == 'And':
            st[i] = st[i].lower()
        else:
            continue
    st = ' '.join(st)
    return st
    


df_census['State/UT'] = df_census['State/UT'].apply(lambda x:capital(x.split()))
df_census['State/UT'] = df_census['State/UT'].apply(lambda x:lowerAnd(x))
df_census['State/UT']
# Out:
# 0                Jammu and Kashmir
# 1                Jammu and Kashmir
# 2                Jammu and Kashmir
# 3                Jammu and Kashmir
# 4                Jammu and Kashmir
#                   ...
# 635                    Pondicherry
# 636                    Pondicherry
# 637    Andaman and Nicobar Islands
# 638    Andaman and Nicobar Islands
# 639    Andaman and Nicobar Islands
# Name: State/UT, Length: 640, dtype: object

# %%
telangana_dist = ['Adilabad',
    'Nizamabad',
    'Karimnagar',
    'Medak',
    'Hyderabad',
    'Rangareddy',
    'Mahbubnagar',
    'Nalgonda',
    'Warangal',
    'Khammam']
    
df_census['State/UT'] = df_census.apply(lambda x:'Telangana' if x['District name'] in telangana_dist else x['State/UT'], axis = 1)
# df_renamed['State/UT'] = df_renamed.apply(lambda x:'Laddakh' if x['District'] in ['Leh','Kargil'] else x['State/UT'], axis = 1)
df_census
# Out:
#      District code                     State/UT              District name  \
# 0                1            Jammu and Kashmir                    Kupwara
# 1                2            Jammu and Kashmir                     Badgam
# 2                3            Jammu and Kashmir                Leh(Ladakh)
# 3                4            Jammu and Kashmir                     Kargil
# 4                5            Jammu and Kashmir                      Punch
# ..             ...                          ...                        ...
# 635            636                  Pondicherry                       Mahe
# 636            637                  Pondicherry                   Karaikal
# 637            638  Andaman and Nicobar Islands                   Nicobars
# 638            639  Andaman and Nicobar Islands  North  AND Middle Andaman
# 639            640  Andaman and Nicobar Islands              South Andaman
#
# ...

# %%
census_state = sorted(df_census['State/UT'].unique())
hospital_state = sorted(df_hospital['State/UT'].unique())

# %%
uncommon = list(set(census_state)-set(hospital_state))+list(set(hospital_state)-set(census_state))
uncommon
# Out:
# ['Orissa',
#  'Andaman and Nicobar Islands',
#  'Jammu and Kashmir',
#  'Dadra and Nagar Haveli',
#  'Daman and Diu',
#  'Pondicherry',
#  'Nct Of Delhi',
#  'Daman & Diu',
#  'Jammu & Kashmir',
#  'Andaman & Nicobar Islands',
#  'Odisha',
#  'All India',
#  'Dadra & Nagar Haveli',
#  'Delhi',
#  'Puducherry']

# %%
changed_state_names = {'Nct Of Delhi':'Delhi',
                       'Andaman & Nicobar Islands':'Andaman and Nicobar Islands',
                       'Daman & Diu': 'Daman and Diu',
                       'Puducherry': 'Pondicherry',
                       'Jammu & Kashmir': 'Jammu and Kashmir',
                       'Orissa': 'Odisha',
                       'Dadra & Nagar Haveli': 'Dadra and Nagar Haveli'}

# %%
df_hospital['State/UT'] = df_hospital['State/UT'].apply(lambda x:changed_state_names[x] if x in changed_state_names.keys() else x)
df_hospital
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 0   Andaman and Nicobar Islands                                     27
# 1                Andhra Pradesh                                   1417
# 2             Arunachal Pradesh                                    122
# 3                         Assam                                   1007
# 4                         Bihar                                   2007
# 5                    Chandigarh                                     40
# 6                  Chhattisgarh                                    813
# 7        Dadra and Nagar Haveli                                      9
# 8                 Daman and Diu                                      4
# 9                         Delhi                                    534
# 10                          Goa                                     31
# 11                      Gujarat                                   1770
# ...

# %%
df_hospital.to_csv('C:/Users/raiti/OneDrive/Desktop/Projects/Python Project Healthcare/Python Project - Healthcare Census/Clean_Data/all_hospitals.csv')

# %% [markdown]
# ## Problem Statement 12: (Analyze Healthcare facility disparity)
# Visually represent how many hospital beds are there for every 10,000 people in each state or union territory. The national value should also be represented in the same visualization such that the value for each state can be compared to it.
# Hint:
#
#
# Report three States/UTs which have the least amount of beds for their population so that more beds can be added to the hospitals in respective states.

# %%
df_state_population = pd.DataFrame(df_census.groupby('State/UT')['Population'].sum())
df_state_population['State/UT'] = df_state_population.index.values
df_state_population
# Out:
#                               Population                     State/UT
# State/UT
# Andaman and Nicobar Islands     142439.0  Andaman and Nicobar Islands
# Andhra Pradesh                44869401.0               Andhra Pradesh
# Arunachal Pradesh              1291651.0            Arunachal Pradesh
# Assam                         28536984.0                        Assam
# Bihar                        101880306.0                        Bihar
# Chandigarh                     1055450.0                   Chandigarh
# Chhattisgarh                  25545198.0                 Chhattisgarh
# Dadra and Nagar Haveli          343709.0       Dadra and Nagar Haveli
# Daman and Diu                   243247.0                Daman and Diu
# Goa                            1458545.0                          Goa
# Gujarat                       52993858.0                      Gujarat
# Haryana                       23181370.0                      Haryana
# ...

# %%
df_state_population['State/UT'] = df_state_population['State/UT'].apply(lambda x:changed_state_names[x] if x in changed_state_names.keys() else x)
df_state_population.set_index(df_state_population['State/UT'], inplace = True)

# %%
df_state_population
# Out:
#                               Population                     State/UT
# State/UT
# Andaman and Nicobar Islands     142439.0  Andaman and Nicobar Islands
# Andhra Pradesh                44869401.0               Andhra Pradesh
# Arunachal Pradesh              1291651.0            Arunachal Pradesh
# Assam                         28536984.0                        Assam
# Bihar                        101880306.0                        Bihar
# Chandigarh                     1055450.0                   Chandigarh
# Chhattisgarh                  25545198.0                 Chhattisgarh
# Dadra and Nagar Haveli          343709.0       Dadra and Nagar Haveli
# Daman and Diu                   243247.0                Daman and Diu
# Goa                            1458545.0                          Goa
# Gujarat                       52993858.0                      Gujarat
# Haryana                       23181370.0                      Haryana
# ...

# %%
df_hospital['HospitalBeds'] = df_hospital['HospitalBeds'].apply(lambda x:int(x.replace(',','')))
# df_hospital['HospitalBeds'] = df_hospital['HospitalBeds'].astype(int)
type(df_hospital['HospitalBeds'][0])
# Out:
# numpy.int64

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
all_india_sum = df_state_population['Population'].sum()
df_state_population.loc['All India'] = all_india_sum
df_state_population = pd.DataFrame(round(df_state_population['Population'],1))

# %%
df_state_population
# Out:
#                               Population
# State/UT
# Andaman and Nicobar Islands     142439.0
# Andhra Pradesh                44869401.0
# Arunachal Pradesh              1291651.0
# Assam                         28536984.0
# Bihar                        101880306.0
# Chandigarh                     1055450.0
# Chhattisgarh                  25545198.0
# Dadra and Nagar Haveli          343709.0
# Daman and Diu                   243247.0
# Goa                            1458545.0
# Gujarat                       52993858.0
# Haryana                       23181370.0
# Himachal Pradesh               6864602.0
# Jammu and Kashmir             12064467.0
# Jharkhand                     31485796.0
# Karnataka                     59248274.0
# Kerala                        33406061.0
# Lakshadweep                      64473.0
# Madhya Pradesh                68065277.0
# Maharashtra                   80476953.0
# Manipur                        2855794.0
# Meghalaya                      2824555.0
# ...

# %%
df_hospital_beds = pd.DataFrame([df_hospital['HospitalBeds']]).transpose()

# %%
df_hospital_beds.set_index(df_hospital['State/UT'], inplace = True)
df_hospital_beds
# Out:
#                              HospitalBeds
# State/UT
# Andaman and Nicobar Islands          1246
# Andhra Pradesh                      60799
# Arunachal Pradesh                    2320
# Assam                               19115
# Bihar                               17796
# Chandigarh                           3756
# Chhattisgarh                        14354
# Dadra and Nagar Haveli                568
# Daman and Diu                         298
# Delhi                               20572
# Goa                                  2666
# Gujarat                             41129
# Haryana                             13841
# Himachal Pradesh                     8706
# Jammu and Kashmir                   11342
# Jharkhand                            7404
# Karnataka                           56333
# Kerala                              39511
# Lakshadweep                           250
# Madhya Pradesh                      38140
# Maharashtra                         68998
# ...

# %%
df_state_population
# Out:
#                               Population
# State/UT
# Andaman and Nicobar Islands     142439.0
# Andhra Pradesh                44869401.0
# Arunachal Pradesh              1291651.0
# Assam                         28536984.0
# Bihar                        101880306.0
# Chandigarh                     1055450.0
# Chhattisgarh                  25545198.0
# Dadra and Nagar Haveli          343709.0
# Daman and Diu                   243247.0
# Goa                            1458545.0
# Gujarat                       52993858.0
# Haryana                       23181370.0
# Himachal Pradesh               6864602.0
# Jammu and Kashmir             12064467.0
# Jharkhand                     31485796.0
# Karnataka                     59248274.0
# Kerala                        33406061.0
# Lakshadweep                      64473.0
# Madhya Pradesh                68065277.0
# Maharashtra                   80476953.0
# Manipur                        2855794.0
# Meghalaya                      2824555.0
# ...

# %%
((df_hospital_beds['HospitalBeds']/df_state_population['Population'])*10000).plot(kind = "bar", label = 'States')
plt.axhline(y=6, color='r', linewidth=2, linestyle='--', alpha=0.5, label = "National Standard")
plt.legend(loc='upper left', fontsize='medium', framealpha=0.5)
plt.title('Hospital Beds per 10000 persons')
plt.legend()
plt.show()

# %%
len(df_state_population),len(df_hospital_beds)
# Out:
# (37, 37)

# %%
# df_hospital_beds_sortedsorted(df_hospital_beds['HospitalBeds'])

# %% [markdown]
# ## Problem Statement 13: (Multi-line header)
# The header in (Data/government_hospitals.csv) is in 2 rows
# States/UTs	Rural hospitals	Urban hospitals	As on
# 	No.	Beds	No.	Beds
#
# The headers are required to be edited for ease of future use as well as for the sake of uniformity.
#
# Import and update the data in a way that it has the following column names
#
# State/UT
#
# Rural_Government_Hospitals
#
# Rural_Government_Beds
#
# Urban_Government_Hospitals
#
# Urban_Government_Beds
#
# Last_Updated

# %%
df_raw_govt_hosp = pd.read_csv('C:/Users/raiti/OneDrive/Desktop/Projects/Python Project Healthcare/Python Project - Healthcare Census/Data/government_hospitals.csv',header=[0, 1])
df_govt_hosp = df_raw_govt_hosp.copy()
df_govt_hosp
# Out:
#                    States/UTs Rural hospitals Unnamed: 2_level_0  \
#            Unnamed: 0_level_1             No.               Beds
# 0              Andhra Pradesh             193               6480
# 1          Arunachal Pradesh*             208               2136
# 2                       Assam            1176              10944
# 3                       Bihar             930               6083
# 4                Chhattisgarh             169               5070
# 5                        Goa*              17               1405
# 6                     Gujarat             364              11715
# 7                    Haryana*             609               6690
# 8           Himachal Pradesh*             705               5665
# 9             Jammu & Kashmir              56               7234
# 10                  Jharkhand             519               5842
# 11                 Karnataka*            2471              21072
# ...

# %%
df_govt_hosp.columns = ['State/UT','Rural_Government_Hospitals', 'Rural_Government_Beds', 'Urban_Government_Hospitals', 'Urban_Government_Beds', 'Last_Updated']

# %%
df_govt_hosp
# Out:
#                      State/UT  Rural_Government_Hospitals  \
# 0              Andhra Pradesh                         193
# 1          Arunachal Pradesh*                         208
# 2                       Assam                        1176
# 3                       Bihar                         930
# 4                Chhattisgarh                         169
# 5                        Goa*                          17
# 6                     Gujarat                         364
# 7                    Haryana*                         609
# 8           Himachal Pradesh*                         705
# 9             Jammu & Kashmir                          56
# 10                  Jharkhand                         519
# 11                 Karnataka*                        2471
# 12                     Kerala                         981
# 13             Madhya Pradesh                         334
# 14                Maharashtra                         273
# ...

# %% [markdown]
# ## Problem Statement 14: (Data update and code reuse)
#
# The ”Last_Updated” column contains a date that is in the format  DD.MM.YYYY but in the future, the date is required in a different format (YYYY-MM-DD)  update the date to the required format.
#
#
# The State/UT names have some different formats compared to other census and housing data. Fix those issues using the function created earlier. If the function created earlier for all_hospitals cannot be used for government_hospital then edit the function so that it can be used for both.
#
#
# Create a new file “government_hospital.csv” in the “Clean” folder and save all the government hospital data after the update.

# %%
df_govt_hosp = df_govt_hosp.fillna(0)
df_govt_hosp['Last_Updated'] = df_govt_hosp['Last_Updated'].astype(str)

# %%
df_govt_hosp['Last_Updated'] = df_govt_hosp['Last_Updated'].apply(lambda x:x.replace('.','-'))

# %%
df_govt_hosp['State/UT'] = df_govt_hosp['State/UT'].apply(lambda x:x.replace('*',''))

# %%
df_govt_hosp
# Out:
#                      State/UT  Rural_Government_Hospitals  \
# 0              Andhra Pradesh                         193
# 1           Arunachal Pradesh                         208
# 2                       Assam                        1176
# 3                       Bihar                         930
# 4                Chhattisgarh                         169
# 5                         Goa                          17
# 6                     Gujarat                         364
# 7                     Haryana                         609
# 8            Himachal Pradesh                         705
# 9             Jammu & Kashmir                          56
# 10                  Jharkhand                         519
# 11                  Karnataka                        2471
# 12                     Kerala                         981
# 13             Madhya Pradesh                         334
# 14                Maharashtra                         273
# ...

# %%
df_govt_hosp['State/UT'] = df_govt_hosp['State/UT'].apply(lambda x:changed_state_names[x] if x in changed_state_names.keys() else x)
df_govt_hosp['State/UT'][36]
# Out:
# 'INDIA'

# %%
df_govt_hosp['State/UT'][36] = 'All India'
# Out:
# C:\Users\raiti\AppData\Local\Temp\ipykernel_12396\2209819007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_govt_hosp['State/UT'][36] = 'All India'

# %%
df_govt_hosp
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                         193
# 1             Arunachal Pradesh                         208
# 2                         Assam                        1176
# 3                         Bihar                         930
# 4                  Chhattisgarh                         169
# 5                           Goa                          17
# 6                       Gujarat                         364
# 7                       Haryana                         609
# 8              Himachal Pradesh                         705
# 9             Jammu and Kashmir                          56
# 10                    Jharkhand                         519
# 11                    Karnataka                        2471
# 12                       Kerala                         981
# 13               Madhya Pradesh                         334
# 14                  Maharashtra                         273
# ...

# %%
df_govt_hosp.to_csv('C:/Users/raiti/OneDrive/Desktop/Projects/Python Project Healthcare/Python Project - Healthcare Census/Clean_Data/government_hospital.csv')

# %% [markdown]
# ## Problem Statement 15: (Government healthcare facility disparity)
#
# Since the resources are limited, it is required to identify the region which lacks the healthcare facility the most for creating new government hospitals.
#
# An idea was suggested* that first the three States/UTs which have the least amount of beds (in all hospitals government and private) for their population is identified. Among those three the state which has the least number of government hospitals can be recommended for setting up a new government hospital.

# %%
df_least_beds = df_govt_hosp[['State/UT', 'Rural_Government_Hospitals', 'Urban_Government_Hospitals']]
df_least_beds['Total_Hospitals'] = df_least_beds['Rural_Government_Hospitals']+df_least_beds['Urban_Government_Hospitals']
# Out:
# C:\Users\raiti\AppData\Local\Temp\ipykernel_12396\2375195723.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_least_beds['Total_Hospitals'] = df_least_beds['Rural_Government_Hospitals']+df_least_beds['Urban_Government_Hospitals']

# %%
df_least_beds_sorted = df_least_beds.sort_values('Total_Hospitals')

# %%
df_top3_least_beds = df_least_beds_sorted.head(3)

# %%
df_top3_least_beds[df_top3_least_beds['Rural_Government_Hospitals'] == df_top3_least_beds['Rural_Government_Hospitals'].min()]['State/UT']
# Out:
# 30    Chandigarh
# Name: State/UT, dtype: object

# %% [markdown]
# ## World Health Organization Standards
# According to WHO standards, a minimum of 3 beds per 1000 people is required. Monica wants to analyse whether different regions in India as well as the nation as a whole are up to that standard. If not, how many facilities are required to fill the gap?
#
# ## Problem Statement 16: (Gap in number of beds)
# Visually represent the difference between the expected number of hospital beds and the available number of hospital beds in each State/UT, as well as at the national level (if any).

# %%
df_govt_hosp
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                         193
# 1             Arunachal Pradesh                         208
# 2                         Assam                        1176
# 3                         Bihar                         930
# 4                  Chhattisgarh                         169
# 5                           Goa                          17
# 6                       Gujarat                         364
# 7                       Haryana                         609
# 8              Himachal Pradesh                         705
# 9             Jammu and Kashmir                          56
# 10                    Jharkhand                         519
# 11                    Karnataka                        2471
# 12                       Kerala                         981
# 13               Madhya Pradesh                         334
# 14                  Maharashtra                         273
# ...

# %%
sorted(df_govt_hosp['State/UT'].unique()) == sorted(df_state_population.index.values)
# Out:
# True

# %%
df_govt_hosp_sorted = df_govt_hosp.sort_values('State/UT')

# %%
df_govt_hosp_sorted['Total Beds'] = df_govt_hosp_sorted['Rural_Government_Beds'] + df_govt_hosp_sorted['Urban_Government_Beds']
df_total_beds = pd.DataFrame([df_govt_hosp_sorted['State/UT'],df_govt_hosp_sorted['Total Beds']]).transpose()
df_total_beds.set_index('State/UT', inplace = True)
df_total_beds
# Out:
#                             Total Beds
# State/UT
# All India                       710761
# Andaman and Nicobar Islands       1075
# Andhra Pradesh                   23138
# Arunachal Pradesh                 2404
# Assam                            17142
# Bihar                            12019
# Chandigarh                         778
# Chhattisgarh                      9412
# Dadra and Nagar Haveli             589
# Daman and Diu                      240
# Delhi                            24383
# Goa                               3013
# Gujarat                          32280
# Haryana                          11240
# Himachal Pradesh                 12399
# Jammu and Kashmir                11651
# Jharkhand                        10784
# Karnataka                        70165
# Kerala                           38004
# Lakshadweep                        300
# Madhya Pradesh                   28839
# Maharashtra                      51446
# Manipur                           1427
# ...

# %%
df_state_population.sort_index()
# Out:
#                               Population
# State/UT
# All India                   1130097898.0
# Andaman and Nicobar Islands     142439.0
# Andhra Pradesh                44869401.0
# Arunachal Pradesh              1291651.0
# Assam                         28536984.0
# Bihar                        101880306.0
# Chandigarh                     1055450.0
# Chhattisgarh                  25545198.0
# Dadra and Nagar Haveli          343709.0
# Daman and Diu                   243247.0
# Delhi                         16787941.0
# Goa                            1458545.0
# Gujarat                       52993858.0
# Haryana                       23181370.0
# Himachal Pradesh               6864602.0
# Jammu and Kashmir             12064467.0
# Jharkhand                     31485796.0
# Karnataka                     59248274.0
# Kerala                        33406061.0
# Lakshadweep                      64473.0
# Madhya Pradesh                68065277.0
# Maharashtra                   80476953.0
# ...

# %%
((df_total_beds['Total Beds']/df_state_population.sort_index()['Population'])*1000).plot(kind = "bar", label = 'State/UT')
plt.axhline(y=3, color='r', linewidth=2, linestyle='--', alpha=0.5, label = "WHO Standard")
plt.legend(loc='upper left', fontsize='medium', framealpha=0.5)
plt.title('Hospital Beds per 1000 persons')
plt.legend()
plt.show()

# %% [markdown]
# ## Problem Statement 17: (Hospitals required to meet the standards)
#
# In a hypothetical situation if the government wishes to fill the gap between the available facility and the WHO standards all by itself how many government hospitals may be required in each state or union territory as well as at the national level?
#
# Find the average number of beds in a government hospital. Divide it by the gap in the number of beds to reach the standards in the region, and round the number to the nearest integer to find the value.
# Represent the findings visually.

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df_govt_hosp_sorted['Total_Beds'] = df_govt_hosp_sorted['Rural_Government_Beds']+df_govt_hosp_sorted['Urban_Government_Beds']
df_govt_hosp_sorted['Total_Hospitals'] = df_govt_hosp_sorted['Rural_Government_Hospitals']+df_govt_hosp_sorted['Urban_Government_Hospitals']
df_govt_hosp_sorted['Beds_per_Hospital'] = df_govt_hosp_sorted['Total_Beds']/df_govt_hosp_sorted['Total_Hospitals']

# %%
df_govt_hosp_sorted
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 36                    All India                       19810
# 29  Andaman and Nicobar Islands                          27
# 0                Andhra Pradesh                         193
# 1             Arunachal Pradesh                         208
# 2                         Assam                        1176
# 3                         Bihar                         930
# 30                   Chandigarh                           0
# 4                  Chhattisgarh                         169
# 31       Dadra and Nagar Haveli                          10
# 32                Daman and Diu                           5
# 33                        Delhi                           0
# 5                           Goa                          17
# 6                       Gujarat                         364
# 7                       Haryana                         609
# 8              Himachal Pradesh                         705
# ...

# %%
df_gap_in_beds = pd.DataFrame()

# %%
df_gap_in_beds['Gap_in_Beds_per_1k'] = (3-(df_total_beds['Total Beds']/df_state_population.sort_index()['Population'])*1000)

# %%
df_state_population_sorted = df_state_population.sort_index()

# %%
df_gap_in_beds['Beds_Needed'] = ((df_state_population_sorted['Population']*df_gap_in_beds['Gap_in_Beds_per_1k'])/1000)

# %%
df_hosp_needed = pd.DataFrame([df_govt_hosp_sorted['State/UT'],df_govt_hosp_sorted['Beds_per_Hospital']]).transpose()
df_hosp_needed.set_index('State/UT', inplace = True)
df_hosp_needed
# Out:
#                             Beds_per_Hospital
# State/UT
# All India                              30.140
# Andaman and Nicobar Islands            35.833
# Andhra Pradesh                         89.682
# Arunachal Pradesh                      11.028
# Assam                                  13.982
# Bihar                                  11.635
# Chandigarh                            194.500
# Chhattisgarh                           43.981
# Dadra and Nagar Haveli                 53.545
# Daman and Diu                          48.000
# Delhi                                 223.697
# Goa                                    71.738
# Gujarat                                66.420
# Haryana                                16.826
# Himachal Pradesh                       15.479
# Jammu and Kashmir                      88.265
# Jharkhand                              19.431
# Karnataka                              24.663
# Kerala                                 29.691
# ...

# %%
df_gap_in_beds
# Out:
#                             Gap_in_Beds_per_1k Beds_Needed
# State/UT
# All India                                2.371 2679532.694
# Andaman and Nicobar Islands             -4.547    -647.683
# Andhra Pradesh                           2.484  111470.203
# Arunachal Pradesh                        1.139    1470.953
# Assam                                    2.399   68468.952
# Bihar                                    2.882  293621.918
# Chandigarh                               2.263    2388.350
# Chhattisgarh                             2.632   67223.594
# Dadra and Nagar Haveli                   1.286     442.127
# Daman and Diu                            2.013     489.741
# Delhi                                    1.548   25980.823
# Goa                                      0.934    1362.635
# Gujarat                                  2.391  126701.574
# Haryana                                  2.515   58304.110
# Himachal Pradesh                         1.194    8194.806
# ...

# %%
df_gap_in_beds['Hospitals_Needed'] = df_gap_in_beds['Beds_Needed']/df_hosp_needed['Beds_per_Hospital']

# %%
df_gap_in_beds
# Out:
#                             Gap_in_Beds_per_1k Beds_Needed Hospitals_Needed
# State/UT
# All India                                2.371 2679532.694        88902.936
# Andaman and Nicobar Islands             -4.547    -647.683          -18.075
# Andhra Pradesh                           2.484  111470.203         1242.947
# Arunachal Pradesh                        1.139    1470.953          133.389
# Assam                                    2.399   68468.952         4896.916
# Bihar                                    2.882  293621.918        25235.996
# Chandigarh                               2.263    2388.350           12.279
# Chhattisgarh                             2.632   67223.594         1528.458
# Dadra and Nagar Haveli                   1.286     442.127            8.257
# Daman and Diu                            2.013     489.741           10.203
# Delhi                                    1.548   25980.823          116.143
# ...
